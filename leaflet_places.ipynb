# %% [markdown]
# # Leaflet integrations in Jupyter notebooks for interactive maps

# %%
from ipyleaflet import *

# %%
# example map
m = Map(center=(52, 10), zoom=8, basemap=basemaps.Esri.DeLorme)
m
# Out:
# Map(basemap={'url': 'http://server.arcgisonline.com/ArcGIS/rest/services/Specialty/DeLorme_World_Base_Map/MapS…

# %% [markdown]
# # Load collected data
#
# Data was collected using the Google Places API and saved in two batches to .csv files.

# %%
import pandas as pd
places_df1 = pd.read_csv('data/places_include_distance.csv')
places_df2 = pd.read_csv('data/places_include_distance2.csv')
places_df = pd.concat([places_df1, places_df2], ignore_index=True)
print(places_df.columns)
places_df.describe()
# Out:
# Index(['country', 'geometry', 'icon', 'id', 'ikea_address', 'ikea_location',
#        'ikea_place_id', 'ikea_rating', 'ikea_user_ratings_total', 'name',
#        'opening_hours', 'photos', 'place_id', 'plus_code', 'price_level',
#        'rating', 'reference', 'scope', 'type', 'types', 'user_ratings_total',
#        'vicinity', 'distance_to_ikea', 'duration_to_ikea'],
#       dtype='object')
#         ikea_rating  ikea_user_ratings_total   price_level        rating  \
# count  32869.000000             32869.000000  11045.000000  28306.000000
# mean       4.157556              5295.502297      1.634767      4.061846
# std        0.384429              3744.362241      0.539851      0.639496
# min        0.000000                 0.000000      1.000000      1.000000
# 25%        4.100000              2998.000000      1.000000      3.800000
# 50%        4.200000              4890.000000      2.000000      4.100000
# 75%        4.300000              6755.000000      2.000000      4.500000
# max        4.900000             19388.000000      4.000000      5.000000
#
#        user_ratings_total  distance_to_ikea  duration_to_ikea
# count        28306.000000      32869.000000       32869.00000
# mean           132.055183       3326.950135         410.85281
# std            361.987164       2569.078801         213.41079
# min              1.000000          0.000000           0.00000
# 25%              7.000000       1404.000000         253.00000
# 50%             34.000000       2754.000000         389.00000
# 75%            125.000000       4642.000000         546.00000
# max          19391.000000      28728.000000        1885.00000

# %%
places_df.head()
# Out:
#            country                                           geometry  \
# 0  the Netherlands  {'location': {'lat': 52.0097797, 'lng': 4.3917...
# 1  the Netherlands  {'location': {'lat': 52.01090180000001, 'lng':...
# 2  the Netherlands  {'location': {'lat': 52.0065033, 'lng': 4.3716...
# 3  the Netherlands  {'location': {'lat': 52.006248, 'lng': 4.37133...
# 4  the Netherlands  {'location': {'lat': 52.0130013, 'lng': 4.3656...
#
#                                                 icon  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...
# 1  https://maps.gstatic.com/mapfiles/place_api/ic...
# 2  https://maps.gstatic.com/mapfiles/place_api/ic...
# 3  https://maps.gstatic.com/mapfiles/place_api/ic...
# 4  https://maps.gstatic.com/mapfiles/place_api/ic...
#
#                                          id  \
# 0  ae42128f873d1ed433826e1377ccdcb677c69e11
# 1  72e194fe338e76aa519c7e33538930ecc700a487
# 2  0e1663ff496c39cfe6bc494abcb7ac619a53024d
# 3  bba642eb2e52acc2b1adf919d1289f9f6b36933c
# 4  92c58753b772dff36d9bc255d2cd92a3b0caa4a1
#
#                                      ikea_address  \
# 0  Olof Palmestraat 1, 2616 LN Delft, Netherlands
# 1  Olof Palmestraat 1, 2616 LN Delft, Netherlands
# 2  Olof Palmestraat 1, 2616 LN Delft, Netherlands
# 3  Olof Palmestraat 1, 2616 LN Delft, Netherlands
# 4  Olof Palmestraat 1, 2616 LN Delft, Netherlands
#
#                                   ikea_location                ikea_place_id  \
# 0  {'lat': 52.01298449999999, 'lng': 4.3815153}  ChIJo6I07vC1xUcRZA27z1-1Q1c
# 1  {'lat': 52.01298449999999, 'lng': 4.3815153}  ChIJo6I07vC1xUcRZA27z1-1Q1c
# 2  {'lat': 52.01298449999999, 'lng': 4.3815153}  ChIJo6I07vC1xUcRZA27z1-1Q1c
# 3  {'lat': 52.01298449999999, 'lng': 4.3815153}  ChIJo6I07vC1xUcRZA27z1-1Q1c
# 4  {'lat': 52.01298449999999, 'lng': 4.3815153}  ChIJo6I07vC1xUcRZA27z1-1Q1c
#
#    ikea_rating  ikea_user_ratings_total                    name  \
# 0          4.2                    11969            Taste Coffee
# 1          4.2                    11969         De Nieuwe Prins
# 2          4.2                    11969             the Bouwpub
# 3          4.2                    11969  Espressobar Vascobello
# 4          4.2                    11969            Café 1Eighty
#
#         ...        price_level rating                    reference   scope  \
# 0       ...                NaN    4.0  ChIJ840zcgnKxUcRNetK2uHnSww  GOOGLE
# 1       ...                2.0    4.4  ChIJo88kSOm1xUcRlWe3_K81oY4  GOOGLE
# 2       ...                1.0    4.6  ChIJw-2iwey1xUcReprW4owZ3u8  GOOGLE
# 3       ...                NaN    3.0  ChIJEeM9A-21xUcRfOy3s3W8c6w  GOOGLE
# 4       ...                NaN    4.1  ChIJExYA-Oi1xUcRejXJldLWnbY  GOOGLE
#
#    type                                              types user_ratings_total  \
# 0  cafe  ['cafe', 'store', 'point_of_interest', 'food',...                2.0
# 1  cafe  ['cafe', 'point_of_interest', 'food', 'establi...               14.0
# 2  cafe  ['cafe', 'point_of_interest', 'food', 'establi...              220.0
# 3  cafe  ['cafe', 'store', 'point_of_interest', 'food',...                6.0
# 4  cafe  ['cafe', 'point_of_interest', 'food', 'establi...               14.0
#
#                            vicinity distance_to_ikea duration_to_ikea
# 0  Graaf Willem II Laan 8, Delfgauw             2646              360
# 1              Oosteinde 1-3, Delft             2227              410
# 2            Julianalaan 134, Delft             1745              337
# 3            Zuidplantsoen 6, Delft             1722              329
# 4         Oranje Plantage 19, Delft             1870              331
#
# [5 rows x 24 columns]

# %%
import json

# %%
from ipyleaflet import Marker

center = (52.0097797, 4.3917406)

m = Map(center=center, zoom=5)

for ikea_id in places_df['ikea_place_id'].unique():
    places_subset = places_df.query("ikea_place_id=='%s'" % ikea_id)
    marker_tuple = tuple(
        Marker(location=[x for x in eval(geo)['location'].values()],
                          title=title, rise_on_hover=True) \
                    for geo,title in zip(places_subset['geometry'][:5], places_subset['name'][:5])
    )
    marker_cluster = MarkerCluster(markers = marker_tuple)
    
    m.add_layer(marker_cluster)
# marker = Marker(location=center, draggable=False)
# m.add_layer(layer_group);

# %%
from ipyleaflet import Marker

center = (52.0097797, 4.3917406)

# initialize map
m = Map(center=center, zoom=2)

# add markers for each ikea location
marker_group = [Marker(location=(eval(x)['lat'], eval(x)['lng']), draggable=False) \
                    for x in places_df['ikea_location'].unique()]
m.add_layer(LayerGroup(layers=marker_group))

# add controls
measure = MeasureControl(
    position='bottomleft',
    active_color = 'orange',
    primary_length_unit = 'kilometers'
)
m.add_control(measure)

m.add_control(FullScreenControl())

# show map
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %% [markdown]
# # Number of IKEA's per country
#
# You may be surprised that some big countries don't show more IKEA location (looking at you Sweden). But the Google Places API was restricted to return up to 20 results per country.

# %%
places_df.groupby('country')['ikea_location'].nunique()
# Out:
# country
# Australia          11
# Belgium             8
# Canada             20
# France             20
# Germany            20
# Hong Kong           5
# Italy              20
# Japan               6
# Poland             20
# Spain              13
# Sweden             20
# Taiwan              6
# Turkey              7
# the Netherlands    12
# the UK             20
# the US             20
# Name: ikea_location, dtype: int64

# %% [markdown]
# # Shops around ikeas
#
# We collected shops around IKEA's for our usecase. There are too many to visualize in leaflet at once, so as an example we'll plot 5 shops for every ikea location.

# %%
from ipyleaflet import Marker

center = (52.0097797, 4.3917406)

m = Map(center=center, zoom=5)

for ikea_id in places_df['ikea_place_id'].unique():
    places_subset = places_df.query("ikea_place_id=='%s'" % ikea_id)
    marker_tuple = tuple(
        Marker(location=[x for x in eval(geo)['location'].values()],
                          title=title, rise_on_hover=True) \
                    for geo,title in zip(places_subset['geometry'][:5], places_subset['name'][:5])
    )
    marker_cluster = MarkerCluster(markers = marker_tuple)
    
    m.add_layer(marker_cluster)

    # add controls
measure = MeasureControl(
    position='bottomleft',
    active_color = 'orange',
    primary_length_unit = 'kilometers'
)
m.add_control(measure)

m.add_control(FullScreenControl())

# show map
m
# Out:
# Map(basemap={'url': 'https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png', 'max_zoom': 19, 'attribution': 'Map …

# %% [markdown]
# # Choose an ikea and show all shops

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

def f(ikea_id):
    places_subset = places_df.query("ikea_place_id=='%s'" % ikea_id)
    
    center = eval(places_subset['ikea_location'].unique()[0])
    center_coords = (center['lat'], center['lng'])
    print(center)
    # initial map
    m = Map(center=center_coords, zoom=12)

    
    
#     marker_tuple = tuple(
#         Marker(location=[x for x in eval(geo)['location'].values()],
#                           title=title, rise_on_hover=True) \
#                     for geo,title in zip(places_subset['geometry'][:5], places_subset['name'][:5])
#     )
#     marker_cluster = MarkerCluster(markers = marker_tuple)
    
    marker_group = [Marker(location=[x for x in eval(geo)['location'].values()],
                          title=title, rise_on_hover=True) \
                    for geo,title in zip(places_subset['geometry'], places_subset['name'])]
    
    m.add_layer(LayerGroup(layers=marker_group))
    
    icon = Icon(icon_url='...',
                icon_size=[38, 95], icon_anchor=[22,94])
    mark = Marker(location=center, icon=icon, rotation_angle=90, rotation_origin='22px 94px')
    m.add_layer(mark);
    m.add_layer(Marker(location=center_coords, title=))

    # add controls
    measure = MeasureControl(
        position='bottomleft',
        active_color = 'orange',
        primary_length_unit = 'kilometers'
    )
    m.add_control(measure)

    m.add_control(FullScreenControl())

    # return map
    return(m)

# %%
interact(f, ikea_id=places_df['ikea_place_id'].unique());
# Out:
# interactive(children=(Dropdown(description='ikea_id', options=('ChIJo6I07vC1xUcRZA27z1-1Q1c', 'ChIJ0dxLWH--wEc…
